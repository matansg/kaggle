# %%
import sys
import time
import tensorflow as tf
import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, matplotlib.image as mpimg
# %matplotlib inline

labeled_images = pd.read_csv('First_assigment_handwritten_digits/train.csv')
images = labeled_images.iloc[:,1:]
labels = labeled_images.iloc[:,:1]

# %%
def forward(X, W, b, output_size, lambd = 0):
    assert W.shape == (X.shape[1], output_size)
    assert b.shape == (1, output_size)
    Z = np.dot(X, W) + b
    A = np.exp(Z)
    s = np.sum(A, axis = 1).reshape((X.shape[0], 1))
    A = (A / s) + 1e-15
    
    return A

def backward(X, Y, A):
    dZ = A - Y
    dW = np.dot(X.T, dZ) / X.shape[0]
    db = np.sum(dZ, axis = 0) / X.shape[0]
    
    return dW, db

def update(X, Y, W, b, output_size, learning_rate):
    A = forward(X, W, b, output_size)
    dW, db = backward(X, Y, A)
    
    J = -np.trace(np.dot(Y, np.log(A).T)) / X.shape[0]
    
    return W - learning_rate * dW, b - learning_rate * db, J

def predict(X, W, b, output_size):
    A = forward(X, W, b, output_size)
    return np.argmax(A, axis = 1)

# %%
# %%time
m = 10000
alpha = 0.1
lambd = 0
minibatch_size = 64
iters = 500

X = images.values[:m, :] / 256.
Y = np.zeros((m, 10), dtype = np.int32)
for i in range(m):
    Y[i, labels.values[i, :]] = 1

W = np.random.rand(X.shape[1], 10)
b = np.random.rand(1, 10)

scores = np.array([])

for epoch in range(iters):
    order = np.random.permutation(m)
    epoch_score = 0
    
    for i in range(0, m, minibatch_size):
        W, b, J = update(X[order[i : i + minibatch_size],:],\
                         Y[order[i : i + minibatch_size],:],\
                         W, b, 10, alpha)
        #epoch_score += J
        scores = np.append(scores, J)
    
print(np.sum(predict(X, W, b, 10) == labels.values[:m, :].reshape((m, ))) / m)
plt.plot(scores)
# Out:
# 0.9713
# Wall time: 52.3 s

# %%
m_test = 10000
X_test = images.values[m : m + m_test, :] / 256.
np.sum(predict(X_test, W, b, 10) == labels.values[m : m + m_test, :].reshape((m_test, ))) / m_test
# Out:
# 0.898

# %%
def get_model(name):
    x = tf.placeholder(tf.float32, [None, 784], name = 'x' + name)
    y = tf.placeholder(tf.float32, [None, 10], name = 'y' + name)
    out = tf.contrib.layers.fully_connected(x, 10, activation_fn = None)
    model = tf.nn.softmax(out)
    cost = tf.losses.softmax_cross_entropy(onehot_labels = y, logits = out)
    return model, cost

# %%
# %%time
import time

name = str(time.time())
model, cost = get_model(name)
optimizer = tf.train.GradientDescentOptimizer(alpha).minimize(cost)
init = tf.global_variables_initializer()

scores = np.array([])

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(iters):
        order = np.random.permutation(m)

        for i in range(0, m, minibatch_size):
            _, J = sess.run([optimizer, cost], feed_dict = {'x' + name + ':0' : X[order[i : i + minibatch_size],:],\
                                                            'y' + name + ':0' : Y[order[i : i + minibatch_size],:]})
            scores = np.append(scores, J)
    predictions = sess.run([model], feed_dict = {'x' + name + ':0' : X, 'y' + name + ':0' : Y})[0]
print(np.sum(np.argmax(predictions, axis = 1) == np.argmax(Y, axis = 1)) / m)
plt.plot(scores)
# Out:
# 0.9713
# Wall time: 1min 36s

# %%
J
# Out:
# 0.29954842

# %%
def get_l2_model(layers, last_layer_activation_fn = None):
    x = tf.placeholder(tf.float64, [None, 784])
    y = tf.placeholder(tf.float64, [None, None])
    
    out = x
    for layer in layers[:-1]:
        out = tf.contrib.layers.fully_connected(out, layer, activation_fn = tf.nn.relu)
    out = tf.contrib.layers.fully_connected(out, layers[-1], activation_fn = last_layer_activation_fn)
    
    dist = tf.matmul(out, tf.transpose(out))
    norms = tf.reshape(tf.diag_part(dist), [-1, 1])
    dist = (-2*dist + norms) + tf.transpose(norms) + 1e-6
    
    m = tf.shape(x)[0]
    m = m*(m-1) / 2
    cost = tf.reduce_sum(tf.multiply(y, dist) + tf.divide(1-y, dist)) / m
    
    return x, y, out, cost


m = 10000
iters = 500
minibatch_size = 32

t = 10000

X = images.values[:m, :] / 256.
Y = np.zeros((m, m), dtype = np.float64)
for i in range(m):
    Y[i, :] = np.float64(labels.values[:m, :] == labels.values[i]).reshape(m,)
    
X_test = images.values[m:m+t, :] / 256.
Y_test = np.zeros((t, t), dtype = np.float64)
for i in range(t):
    Y[i, :] = np.float64(labels.values[m:m+t, :] == labels.values[i]).reshape(t,)
    
x, y, out, cost = get_l2_model([50, 10])
optimizer = tf.train.AdamOptimizer().minimize(cost)
init = tf.global_variables_initializer()

scores = np.array([])

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(iters):
        start = time.time()
        
        order = np.random.permutation(m)

        for i in range(0, m, minibatch_size):
            indices = order[i : i + minibatch_size]
            _, J = sess.run([optimizer, cost], feed_dict = {x : X[indices,:], y : Y[indices, :][:, indices]})
            
            scores = np.append(scores, J)
            
        end = time.time()
        print('Epoch #{} ended and took {:.2} seconds'.format(epoch, end - start))
        sys.stdout.flush()
    predictions, = sess.run([out], feed_dict = {x : X_test, y : Y_test})
plt.plot(scores)
# Out:
# Epoch #0 ended and took 1.1 seconds
# Epoch #1 ended and took 0.87 seconds
# Epoch #2 ended and took 0.85 seconds
# Epoch #3 ended and took 0.82 seconds
# Epoch #4 ended and took 0.9 seconds
# Epoch #5 ended and took 0.77 seconds
# Epoch #6 ended and took 0.84 seconds
# Epoch #7 ended and took 0.86 seconds
# Epoch #8 ended and took 0.8 seconds
# Epoch #9 ended and took 0.93 seconds
# Epoch #10 ended and took 0.99 seconds
# Epoch #11 ended and took 0.81 seconds
# Epoch #12 ended and took 0.86 seconds
# Epoch #13 ended and took 0.95 seconds
# Epoch #14 ended and took 0.82 seconds
# Epoch #15 ended and took 0.96 seconds
# Epoch #16 ended and took 1.0 seconds
# Epoch #17 ended and took 0.78 seconds
# Epoch #18 ended and took 0.96 seconds
# Epoch #19 ended and took 0.96 seconds
# Epoch #20 ended and took 1.1 seconds
# Epoch #21 ended and took 0.89 seconds
# Epoch #22 ended and took 0.84 seconds
# Epoch #23 ended and took 0.84 seconds
# Epoch #24 ended and took 0.98 seconds
# Epoch #25 ended and took 0.9 seconds
# Epoch #26 ended and took 0.84 seconds
# Epoch #27 ended and took 0.85 seconds
# Epoch #28 ended and took 0.85 seconds
# Epoch #29 ended and took 0.99 seconds
# Epoch #30 ended and took 1.0 seconds
# Epoch #31 ended and took 0.87 seconds
# Epoch #32 ended and took 0.86 seconds
# Epoch #33 ended and took 0.89 seconds
# Epoch #34 ended and took 0.87 seconds
# Epoch #35 ended and took 0.88 seconds
# Epoch #36 ended and took 1.1 seconds
# Epoch #37 ended and took 0.86 seconds
# Epoch #38 ended and took 0.86 seconds
# Epoch #39 ended and took 1.1 seconds
# Epoch #40 ended and took 0.83 seconds
# Epoch #41 ended and took 0.87 seconds
# Epoch #42 ended and took 0.98 seconds
# Epoch #43 ended and took 0.83 seconds
# Epoch #44 ended and took 0.83 seconds
# Epoch #45 ended and took 0.84 seconds
# Epoch #46 ended and took 0.83 seconds
# Epoch #47 ended and took 0.84 seconds
# Epoch #48 ended and took 0.84 seconds
# Epoch #49 ended and took 0.84 seconds
# Epoch #50 ended and took 0.83 seconds
# Epoch #51 ended and took 0.86 seconds
# Epoch #52 ended and took 0.84 seconds
# Epoch #53 ended and took 0.83 seconds
# Epoch #54 ended and took 0.84 seconds
# Epoch #55 ended and took 0.83 seconds
# Epoch #56 ended and took 0.91 seconds
# Epoch #57 ended and took 1.0 seconds
# Epoch #58 ended and took 0.88 seconds
# Epoch #59 ended and took 0.85 seconds
# Epoch #60 ended and took 0.99 seconds
# Epoch #61 ended and took 0.88 seconds
# Epoch #62 ended and took 0.83 seconds
# Epoch #63 ended and took 0.84 seconds
# Epoch #64 ended and took 0.83 seconds
# Epoch #65 ended and took 0.84 seconds
# Epoch #66 ended and took 0.84 seconds
# Epoch #67 ended and took 0.83 seconds
# Epoch #68 ended and took 0.83 seconds
# Epoch #69 ended and took 0.83 seconds
# Epoch #70 ended and took 0.84 seconds
# Epoch #71 ended and took 0.83 seconds
# Epoch #72 ended and took 0.83 seconds
# Epoch #73 ended and took 0.83 seconds
# Epoch #74 ended and took 0.83 seconds
# Epoch #75 ended and took 0.84 seconds
# Epoch #76 ended and took 0.85 seconds
# Epoch #77 ended and took 0.83 seconds
# Epoch #78 ended and took 0.83 seconds
# Epoch #79 ended and took 0.97 seconds
# Epoch #80 ended and took 0.88 seconds
# Epoch #81 ended and took 0.83 seconds
# Epoch #82 ended and took 0.83 seconds
# Epoch #83 ended and took 0.84 seconds
# Epoch #84 ended and took 0.85 seconds
# Epoch #85 ended and took 0.85 seconds
# Epoch #86 ended and took 0.85 seconds
# Epoch #87 ended and took 0.85 seconds
# Epoch #88 ended and took 0.84 seconds
# Epoch #89 ended and took 0.91 seconds
# Epoch #90 ended and took 1.0 seconds
# Epoch #91 ended and took 0.84 seconds
# Epoch #92 ended and took 0.83 seconds
# Epoch #93 ended and took 0.83 seconds
# Epoch #94 ended and took 0.84 seconds
# Epoch #95 ended and took 0.83 seconds
# Epoch #96 ended and took 0.84 seconds
# Epoch #97 ended and took 0.89 seconds
# Epoch #98 ended and took 1.0 seconds
# Epoch #99 ended and took 0.87 seconds
# Epoch #100 ended and took 0.87 seconds
# Epoch #101 ended and took 0.96 seconds
# Epoch #102 ended and took 0.9 seconds
# Epoch #103 ended and took 0.91 seconds
# Epoch #104 ended and took 0.97 seconds
# Epoch #105 ended and took 1.1 seconds
# Epoch #106 ended and took 0.97 seconds
# Epoch #107 ended and took 0.9 seconds
# Epoch #108 ended and took 1.0 seconds
# Epoch #109 ended and took 0.9 seconds
# Epoch #110 ended and took 0.89 seconds
# Epoch #111 ended and took 0.9 seconds
# Epoch #112 ended and took 1.1 seconds
# Epoch #113 ended and took 1.3 seconds
# Epoch #114 ended and took 1.6 seconds
# Epoch #115 ended and took 1.0 seconds
# Epoch #116 ended and took 1.0 seconds
# Epoch #117 ended and took 1.1 seconds
# Epoch #118 ended and took 1.1 seconds
# Epoch #119 ended and took 0.98 seconds
# Epoch #120 ended and took 1.1 seconds
# Epoch #121 ended and took 0.99 seconds
# Epoch #122 ended and took 0.86 seconds
# Epoch #123 ended and took 1.1 seconds
# Epoch #124 ended and took 0.87 seconds
# Epoch #125 ended and took 0.85 seconds
# Epoch #126 ended and took 0.84 seconds
# Epoch #127 ended and took 0.99 seconds
# Epoch #128 ended and took 0.97 seconds
# Epoch #129 ended and took 0.9 seconds
# Epoch #130 ended and took 1.3 seconds
# Epoch #131 ended and took 0.97 seconds
# Epoch #132 ended and took 0.95 seconds
# Epoch #133 ended and took 0.96 seconds
# Epoch #134 ended and took 1.1 seconds
# Epoch #135 ended and took 0.85 seconds
# Epoch #136 ended and took 0.85 seconds
# Epoch #137 ended and took 0.84 seconds
# Epoch #138 ended and took 0.86 seconds
# Epoch #139 ended and took 0.87 seconds
# Epoch #140 ended and took 0.84 seconds
# Epoch #141 ended and took 0.85 seconds
# Epoch #142 ended and took 0.85 seconds
# Epoch #143 ended and took 0.83 seconds
# Epoch #144 ended and took 0.85 seconds
# Epoch #145 ended and took 0.85 seconds
# Epoch #146 ended and took 0.85 seconds
# Epoch #147 ended and took 0.88 seconds
# Epoch #148 ended and took 0.99 seconds
# Epoch #149 ended and took 0.85 seconds
# Epoch #150 ended and took 0.85 seconds
# Epoch #151 ended and took 0.86 seconds
# Epoch #152 ended and took 0.84 seconds
# Epoch #153 ended and took 0.85 seconds
# Epoch #154 ended and took 0.85 seconds
# Epoch #155 ended and took 1.0 seconds
# Epoch #156 ended and took 0.9 seconds
# Epoch #157 ended and took 0.86 seconds
# Epoch #158 ended and took 1.1 seconds
# Epoch #159 ended and took 0.91 seconds
# Epoch #160 ended and took 0.87 seconds
# Epoch #161 ended and took 1.1 seconds
# Epoch #162 ended and took 0.95 seconds
# Epoch #163 ended and took 0.93 seconds
# Epoch #164 ended and took 1.1 seconds
# Epoch #165 ended and took 1.3 seconds
# Epoch #166 ended and took 0.94 seconds
# Epoch #167 ended and took 1.1 seconds
# Epoch #168 ended and took 0.94 seconds
# Epoch #169 ended and took 0.99 seconds
# Epoch #170 ended and took 0.96 seconds
# Epoch #171 ended and took 0.89 seconds
# Epoch #172 ended and took 0.9 seconds
# Epoch #173 ended and took 1.1 seconds
# Epoch #174 ended and took 0.94 seconds
# Epoch #175 ended and took 0.86 seconds
# Epoch #176 ended and took 0.96 seconds
# Epoch #177 ended and took 0.97 seconds
# Epoch #178 ended and took 0.92 seconds
# Epoch #179 ended and took 1.1 seconds
# Epoch #180 ended and took 1.0 seconds
# Epoch #181 ended and took 1.2 seconds
# Epoch #182 ended and took 0.88 seconds
# Epoch #183 ended and took 0.88 seconds
# Epoch #184 ended and took 0.88 seconds
# Epoch #185 ended and took 1.0 seconds
# Epoch #186 ended and took 1.3 seconds
# Epoch #187 ended and took 1.2 seconds
# Epoch #188 ended and took 0.99 seconds
# Epoch #189 ended and took 0.93 seconds
# Epoch #190 ended and took 0.93 seconds
# Epoch #191 ended and took 0.94 seconds
# Epoch #192 ended and took 1.2 seconds
# Epoch #193 ended and took 1.4 seconds
# Epoch #194 ended and took 1.3 seconds
# Epoch #195 ended and took 0.99 seconds
# Epoch #196 ended and took 1.2 seconds
# Epoch #197 ended and took 0.98 seconds
# Epoch #198 ended and took 0.95 seconds
# Epoch #199 ended and took 0.89 seconds
# Epoch #200 ended and took 0.96 seconds
# Epoch #201 ended and took 1.0 seconds
# Epoch #202 ended and took 0.96 seconds
# Epoch #203 ended and took 1.0 seconds
# Epoch #204 ended and took 0.94 seconds
# Epoch #205 ended and took 0.95 seconds
# Epoch #206 ended and took 1.3 seconds
# Epoch #207 ended and took 1.5 seconds
# Epoch #208 ended and took 0.98 seconds
# Epoch #209 ended and took 1.7 seconds
# Epoch #210 ended and took 1.4 seconds
# Epoch #211 ended and took 1.1 seconds
# Epoch #212 ended and took 1.0 seconds
# Epoch #213 ended and took 0.94 seconds
# Epoch #214 ended and took 0.88 seconds
# Epoch #215 ended and took 0.88 seconds
# Epoch #216 ended and took 0.96 seconds
# Epoch #217 ended and took 0.88 seconds
# Epoch #218 ended and took 0.88 seconds
# Epoch #219 ended and took 0.93 seconds
# Epoch #220 ended and took 1.0 seconds
# Epoch #221 ended and took 0.94 seconds
# Epoch #222 ended and took 1.0 seconds
# Epoch #223 ended and took 0.9 seconds
# Epoch #224 ended and took 0.9 seconds
# Epoch #225 ended and took 1.2 seconds
# Epoch #226 ended and took 1.1 seconds
# Epoch #227 ended and took 1.3 seconds
# Epoch #228 ended and took 1.3 seconds
# Epoch #229 ended and took 1.0 seconds
# Epoch #230 ended and took 0.95 seconds
# Epoch #231 ended and took 1.1 seconds
# Epoch #232 ended and took 1.5 seconds
# Epoch #233 ended and took 1.1 seconds
# Epoch #234 ended and took 1.1 seconds
# Epoch #235 ended and took 1.2 seconds
# Epoch #236 ended and took 1.0 seconds
# Epoch #237 ended and took 0.93 seconds
# Epoch #238 ended and took 1.2 seconds
# Epoch #239 ended and took 1.1 seconds
# Epoch #240 ended and took 1.2 seconds
# Epoch #241 ended and took 1.4 seconds
# Epoch #242 ended and took 0.99 seconds
# Epoch #243 ended and took 1.2 seconds
# Epoch #244 ended and took 1.1 seconds
# Epoch #245 ended and took 1.3 seconds
# Epoch #246 ended and took 1.3 seconds
# Epoch #247 ended and took 1.2 seconds
# Epoch #248 ended and took 1.1 seconds
# Epoch #249 ended and took 1.1 seconds
# Epoch #250 ended and took 1.1 seconds
# Epoch #251 ended and took 1.0 seconds
# Epoch #252 ended and took 0.94 seconds
# Epoch #253 ended and took 0.96 seconds
# Epoch #254 ended and took 0.97 seconds
# Epoch #255 ended and took 1.1 seconds
# Epoch #256 ended and took 1.2 seconds
# Epoch #257 ended and took 1.2 seconds
# Epoch #258 ended and took 1.2 seconds
# Epoch #259 ended and took 1.2 seconds
# Epoch #260 ended and took 0.97 seconds
# Epoch #261 ended and took 0.96 seconds
# Epoch #262 ended and took 1.1 seconds
# Epoch #263 ended and took 0.95 seconds
# Epoch #264 ended and took 0.91 seconds
# Epoch #265 ended and took 1.2 seconds
# Epoch #266 ended and took 0.97 seconds
# Epoch #267 ended and took 0.94 seconds
# Epoch #268 ended and took 1.0 seconds
# Epoch #269 ended and took 1.0 seconds
# Epoch #270 ended and took 1.2 seconds
# Epoch #271 ended and took 1.1 seconds
# Epoch #272 ended and took 0.93 seconds
# Epoch #273 ended and took 0.89 seconds
# Epoch #274 ended and took 0.9 seconds
# Epoch #275 ended and took 0.88 seconds
# Epoch #276 ended and took 0.99 seconds
# Epoch #277 ended and took 0.95 seconds
# Epoch #278 ended and took 0.96 seconds
# Epoch #279 ended and took 0.89 seconds
# Epoch #280 ended and took 0.87 seconds
# Epoch #281 ended and took 0.92 seconds
# Epoch #282 ended and took 0.87 seconds
# Epoch #283 ended and took 0.87 seconds
# Epoch #284 ended and took 0.91 seconds
# Epoch #285 ended and took 0.95 seconds
# Epoch #286 ended and took 1.0 seconds
# Epoch #287 ended and took 1.2 seconds
# Epoch #288 ended and took 1.2 seconds
# Epoch #289 ended and took 1.1 seconds
# Epoch #290 ended and took 0.86 seconds
# Epoch #291 ended and took 0.87 seconds
# Epoch #292 ended and took 0.86 seconds
# Epoch #293 ended and took 0.87 seconds
# Epoch #294 ended and took 0.86 seconds
# Epoch #295 ended and took 0.86 seconds
# Epoch #296 ended and took 0.87 seconds
# Epoch #297 ended and took 0.88 seconds
# Epoch #298 ended and took 0.89 seconds
# Epoch #299 ended and took 0.87 seconds
# Epoch #300 ended and took 0.87 seconds
# Epoch #301 ended and took 0.86 seconds
# Epoch #302 ended and took 0.86 seconds
# Epoch #303 ended and took 0.94 seconds
# Epoch #304 ended and took 1.1 seconds
# Epoch #305 ended and took 0.91 seconds
# Epoch #306 ended and took 0.86 seconds
# Epoch #307 ended and took 0.85 seconds
# Epoch #308 ended and took 0.86 seconds
# Epoch #309 ended and took 0.86 seconds
# Epoch #310 ended and took 0.85 seconds
# Epoch #311 ended and took 0.87 seconds
# Epoch #312 ended and took 0.86 seconds
# Epoch #313 ended and took 0.87 seconds
# Epoch #314 ended and took 0.86 seconds
# Epoch #315 ended and took 0.86 seconds
# Epoch #316 ended and took 0.87 seconds
# Epoch #317 ended and took 0.87 seconds
# Epoch #318 ended and took 0.9 seconds
# Epoch #319 ended and took 0.87 seconds
# Epoch #320 ended and took 0.87 seconds
# Epoch #321 ended and took 0.87 seconds
# Epoch #322 ended and took 1.0 seconds
# Epoch #323 ended and took 1.0 seconds
# Epoch #324 ended and took 0.93 seconds
# Epoch #325 ended and took 0.93 seconds
# Epoch #326 ended and took 0.94 seconds
# Epoch #327 ended and took 0.94 seconds
# Epoch #328 ended and took 0.94 seconds
# Epoch #329 ended and took 0.94 seconds
# Epoch #330 ended and took 0.92 seconds
# Epoch #331 ended and took 0.94 seconds
# Epoch #332 ended and took 0.93 seconds
# Epoch #333 ended and took 0.93 seconds
# Epoch #334 ended and took 0.93 seconds
# Epoch #335 ended and took 0.9 seconds
# Epoch #336 ended and took 0.88 seconds
# Epoch #337 ended and took 0.86 seconds
# Epoch #338 ended and took 0.87 seconds
# Epoch #339 ended and took 0.95 seconds
# Epoch #340 ended and took 0.97 seconds
# Epoch #341 ended and took 0.87 seconds
# Epoch #342 ended and took 0.86 seconds
# Epoch #343 ended and took 0.88 seconds
# Epoch #344 ended and took 0.86 seconds
# Epoch #345 ended and took 0.87 seconds
# Epoch #346 ended and took 0.86 seconds
# Epoch #347 ended and took 0.86 seconds
# Epoch #348 ended and took 0.86 seconds
# Epoch #349 ended and took 0.87 seconds
# Epoch #350 ended and took 0.86 seconds
# Epoch #351 ended and took 0.86 seconds
# Epoch #352 ended and took 0.86 seconds
# Epoch #353 ended and took 0.87 seconds
# Epoch #354 ended and took 0.87 seconds
# Epoch #355 ended and took 0.87 seconds
# Epoch #356 ended and took 0.86 seconds
# Epoch #357 ended and took 0.92 seconds
# Epoch #358 ended and took 1.0 seconds
# Epoch #359 ended and took 0.88 seconds
# Epoch #360 ended and took 0.87 seconds
# Epoch #361 ended and took 0.87 seconds
# Epoch #362 ended and took 0.87 seconds
# Epoch #363 ended and took 0.87 seconds
# Epoch #364 ended and took 0.93 seconds
# Epoch #365 ended and took 1.0 seconds
# Epoch #366 ended and took 1.1 seconds
# Epoch #367 ended and took 0.91 seconds
# Epoch #368 ended and took 0.99 seconds
# Epoch #369 ended and took 0.99 seconds
# Epoch #370 ended and took 0.98 seconds
# Epoch #371 ended and took 0.94 seconds
# Epoch #372 ended and took 0.87 seconds
# Epoch #373 ended and took 0.87 seconds
# Epoch #374 ended and took 0.96 seconds
# Epoch #375 ended and took 1.2 seconds
# Epoch #376 ended and took 1.0 seconds
# Epoch #377 ended and took 1.0 seconds
# Epoch #378 ended and took 0.93 seconds
# Epoch #379 ended and took 1.0 seconds
# Epoch #380 ended and took 1.0 seconds
# Epoch #381 ended and took 1.1 seconds
# Epoch #382 ended and took 1.0 seconds
# Epoch #383 ended and took 1.0 seconds
# Epoch #384 ended and took 1.0 seconds
# Epoch #385 ended and took 0.93 seconds
# Epoch #386 ended and took 1.1 seconds
# Epoch #387 ended and took 1.1 seconds
# Epoch #388 ended and took 1.0 seconds
# Epoch #389 ended and took 1.0 seconds
# Epoch #390 ended and took 1.0 seconds
# Epoch #391 ended and took 1.0 seconds
# Epoch #392 ended and took 0.97 seconds
# Epoch #393 ended and took 0.95 seconds
# Epoch #394 ended and took 0.95 seconds
# Epoch #395 ended and took 0.99 seconds
# Epoch #396 ended and took 0.96 seconds
# Epoch #397 ended and took 0.96 seconds
# Epoch #398 ended and took 0.96 seconds
# Epoch #399 ended and took 0.91 seconds
# Epoch #400 ended and took 0.88 seconds
# Epoch #401 ended and took 0.89 seconds
# Epoch #402 ended and took 0.92 seconds
# Epoch #403 ended and took 0.89 seconds
# Epoch #404 ended and took 0.89 seconds
# Epoch #405 ended and took 0.88 seconds
# Epoch #406 ended and took 0.89 seconds
# Epoch #407 ended and took 0.99 seconds
# Epoch #408 ended and took 0.97 seconds
# Epoch #409 ended and took 0.89 seconds
# Epoch #410 ended and took 0.88 seconds
# Epoch #411 ended and took 0.9 seconds
# Epoch #412 ended and took 0.92 seconds
# Epoch #413 ended and took 0.89 seconds
# Epoch #414 ended and took 0.89 seconds
# Epoch #415 ended and took 0.89 seconds
# Epoch #416 ended and took 0.9 seconds
# Epoch #417 ended and took 0.98 seconds
# Epoch #418 ended and took 1.0 seconds
# Epoch #419 ended and took 1.0 seconds
# Epoch #420 ended and took 1.0 seconds
# Epoch #421 ended and took 1.0 seconds
# Epoch #422 ended and took 1.0 seconds
# Epoch #423 ended and took 1.0 seconds
# Epoch #424 ended and took 1.2 seconds
# Epoch #425 ended and took 1.0 seconds
# Epoch #426 ended and took 1.0 seconds
# Epoch #427 ended and took 1.0 seconds
# Epoch #428 ended and took 1.0 seconds
# Epoch #429 ended and took 1.0 seconds
# Epoch #430 ended and took 1.0 seconds
# Epoch #431 ended and took 1.0 seconds
# Epoch #432 ended and took 1.0 seconds
# Epoch #433 ended and took 1.0 seconds
# Epoch #434 ended and took 1.0 seconds
# Epoch #435 ended and took 1.0 seconds
# Epoch #436 ended and took 1.0 seconds
# Epoch #437 ended and took 1.0 seconds
# Epoch #438 ended and took 1.0 seconds
# Epoch #439 ended and took 1.1 seconds
# Epoch #440 ended and took 1.2 seconds
# Epoch #441 ended and took 1.0 seconds
# Epoch #442 ended and took 1.0 seconds
# Epoch #443 ended and took 1.0 seconds
# Epoch #444 ended and took 1.0 seconds
# Epoch #445 ended and took 1.0 seconds
# Epoch #446 ended and took 1.0 seconds
# Epoch #447 ended and took 1.0 seconds
# Epoch #448 ended and took 1.0 seconds
# Epoch #449 ended and took 1.0 seconds
# Epoch #450 ended and took 1.0 seconds
# Epoch #451 ended and took 1.0 seconds
# Epoch #452 ended and took 1.0 seconds
# Epoch #453 ended and took 1.0 seconds
# Epoch #454 ended and took 1.0 seconds
# Epoch #455 ended and took 1.2 seconds
# Epoch #456 ended and took 1.1 seconds
# Epoch #457 ended and took 1.0 seconds
# Epoch #458 ended and took 1.0 seconds
# Epoch #459 ended and took 1.0 seconds
# Epoch #460 ended and took 1.0 seconds
# Epoch #461 ended and took 1.0 seconds
# Epoch #462 ended and took 1.0 seconds
# Epoch #463 ended and took 1.0 seconds
# Epoch #464 ended and took 1.0 seconds
# Epoch #465 ended and took 1.0 seconds
# Epoch #466 ended and took 1.0 seconds
# Epoch #467 ended and took 1.0 seconds
# Epoch #468 ended and took 1.0 seconds
# Epoch #469 ended and took 1.0 seconds
# Epoch #470 ended and took 1.1 seconds
# Epoch #471 ended and took 1.2 seconds
# Epoch #472 ended and took 1.0 seconds
# Epoch #473 ended and took 1.0 seconds
# Epoch #474 ended and took 1.0 seconds
# Epoch #475 ended and took 1.0 seconds
# Epoch #476 ended and took 1.0 seconds
# Epoch #477 ended and took 1.0 seconds
# Epoch #478 ended and took 1.0 seconds
# Epoch #479 ended and took 1.0 seconds
# Epoch #480 ended and took 1.0 seconds
# Epoch #481 ended and took 1.0 seconds
# Epoch #482 ended and took 1.0 seconds
# Epoch #483 ended and took 1.0 seconds
# Epoch #484 ended and took 1.2 seconds
# Epoch #485 ended and took 1.4 seconds
# Epoch #486 ended and took 1.2 seconds
# Epoch #487 ended and took 1.1 seconds
# Epoch #488 ended and took 1.1 seconds
# Epoch #489 ended and took 1.0 seconds
# Epoch #490 ended and took 1.0 seconds
# Epoch #491 ended and took 1.0 seconds
# Epoch #492 ended and took 1.0 seconds
# Epoch #493 ended and took 1.0 seconds
# Epoch #494 ended and took 1.0 seconds
# Epoch #495 ended and took 1.1 seconds
# Epoch #496 ended and took 1.0 seconds
# Epoch #497 ended and took 1.1 seconds
# Epoch #498 ended and took 1.0 seconds
# Epoch #499 ended and took 1.0 seconds

# %%
p = np.array([predictions[np.where(labels.values == i)[0][0], :] for i in range(10)])
pred = np.array([])
for u in range(X_test.shape[0]):
    pred = np.append(pred, np.argmin(np.linalg.norm(p - predictions[u, :], axis = 1)))

# %%
np.sum(pred == labels.values[m:m+t].reshape((-1,)))
# Out:
# 1190
